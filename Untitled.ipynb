# %%
import pandas as pd

# %%
file_path = r"D:\UES\RS - Time Series analysis and modeling\data\discharge_klu.csv"
df = pd.read_csv(file_path, index_col='Phenomenon', parse_dates=True, skiprows=3)

# %%
df
# Out:
#                            Abfluss (m³/s)
# Phenomenon
# 2010-01-01 00:00:00+01:00           30.84
# 2010-01-01 00:09:00+01:00           30.85
# 2010-01-01 00:15:00+01:00           30.75
# 2010-01-01 00:30:00+01:00           30.64
# 2010-01-01 00:45:00+01:00           30.59
# ...                                   ...
# 2025-12-31 23:35:00+01:00            3.60
# 2025-12-31 23:40:00+01:00            3.63
# 2025-12-31 23:55:00+01:00            3.63
# 2025-12-31 23:55:05+01:00            3.78
# 2025-12-31 23:59:30+01:00            3.82
#
# [1375033 rows x 1 columns]
